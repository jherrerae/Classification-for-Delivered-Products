# %% [markdown]
# <a href="https://colab.research.google.com/github/jherrerae/Project2/blob/main/Project_2_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
filename="/content/drive/MyDrive/Coding Dojo/Classes/Datasets/Company Bankruptcy data.csv"
df=pd.read_csv(filename)
df.head(5)
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
df.shape
# Out:
# (6819, 96)

# %% [markdown]
# First choice: dataset 1
#
# 1) Source of data
#
# Kaggle
#
# https://www.kaggle.com/datasets/fedesoriano/company-bankruptcy-prediction?resource=download
#
# 2) Brief description of data
# The data were collected from the Taiwan Economic Journal for the years 1999 to 2009. Company bankruptcy was defined based on the business regulations of the Taiwan Stock Exchange.
#
# 3) What is the target?
#
# Company Bankruptcy-> Yes or No
# Y - Bankrupt?: Class label
#
#
# 4) Is this a classification or regression problem?
#
# Classification
#
# 5) How many features?
#
# 96 columns
#
# 6) How many rows of data.
#
# 6819
#
# 7) What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset?
#
# Lots of features to evaluate, maybe a PCA is needed to reduce

# %%
filename="/content/drive/MyDrive/Coding Dojo/Classes/Datasets/CO2 Emissions_Canada.csv"
df1=pd.read_csv(filename)
df1.head(5)
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
df1.shape
# Out:
# (7385, 12)

# %% [markdown]
# Second choice: dataset 2
#
# 1) Source of data
#
# Kaggle
#
# https://www.kaggle.com/datasets/debajyotipodder/co2-emission-by-vehicles
#
# 2) Brief description of data The data were collected from the Taiwan Economic Journal for the years 1999 to 2009. Company bankruptcy was defined based on the business regulations of the Taiwan Stock Exchange.
#
# 3) What is the target?
#
# CO2 Emissions(g/km)
#
# 4) Is this a classification or regression problem?
#
# regression
#
# 5) How many features?
#
# 12 columns
#
# 6) How many rows of data.
#
# 7835
#
# 7) What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset?
#
# Combination of categorical and numerical features.
# Analysis ofsome categorical values
